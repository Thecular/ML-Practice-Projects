# %%
#Import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from prompt_toolkit.key_binding.bindings.named_commands import uppercase_word
# %matplotlib inline

# %%
#Load and read file
clinic = pd.read_csv("messy_clinic_appointments.csv")
clinic.head(20)
# Out:
#     patient_id       patient_name  age  gender  appointment_date  \
# 0         1080     Tammy Williams   76  female        2026/02/26
# 1         1074   Megan Strickland   69       F        05/23/2025
# 2         1067   Amanda Schroeder   79       M       30-Nov-2025
# 3         1072  Anthony Mcpherson   47       F        May 18, 25
# 4         1092     Benjamin Brown   45     NaN        2026/03/07
# 5         1057          Joe Sharp   78       1  September 26, 25
# 6         1018   Alexander Harris   22  Female       30-Oct-2025
# 7         1074   Raymond Williams   57       M        2025/04/23
# 8         1041      Dustin Willis   54  female     August 22, 25
# 9         1011     Tina Gallagher   45       M        03/16/2026
# 10        1086    Robert Guerrero   54    male        2025/04/24
# 11        1041       Karen Walker   68       F        2026/03/07
# 12        1057         Chris Rice   61       1        2025/07/31
# 13        1022       Michael Mack   70       M  September 21, 25
# 14        1046     Andrea Hubbard   36       F        2026/03/12
# 15        1025        Brian Jones   23  female       06-Feb-2026
# 16        1027        Kelly Olsen   72    Male     August 27, 25
# 17        1059     Andrew Oconnor   66  Female   November 11, 25
# 18        1086      Dennis Hurley   81       M        04/10/2025
# 19        1033         Paul Brock   76  Female        2025/11/05
#
#      booking_date              doctor   department billing_amount  \
# 0      2024/12/03  Christopher Graham   Cardiology         £425.8
# 1     12-Jun-2024       Brandon Lewis  Orthopedics        €344.26
# 2   August 05, 24      Deanna Edwards    Neurology        €203.34
# 3      09/09/2024       Karen Parsons      General        Rs85.76
# 4      08/17/2024    Andrea Hernandez      General         $84.44
# 5      08/31/2025     Kimberly Fields      General            NaN
# 6      12/29/2024           Jim Jones   Cardiology          €99.0
# 7     28-Mar-2025        James Brooks    Neurology       Rs374.63
# 8      2024/11/07          Jamie Hill      General        $452.37
# 9     12-Dec-2025    Tiffany Gates MD    Neurology        €494.97
# 10    07-Oct-2024         Shane Brown   Cardiology         £91.91
# 11     2024/04/24       Natalie White      General         $82.88
# 12     May 05, 24           Amy Olson    Neurology       Rs277.14
# 13    06-Nov-2024      John Larsen II  Orthopedics        €411.01
# 14     11/08/2025        Andrea Gates   Cardiology         £67.51
# 15     2025/03/09      Robert Navarro  Orthopedics        €163.99
# 16    13-Feb-2025  Christopher Bryant   Cardiology        £252.38
# 17    01-Dec-2024      Christina Hill   Cardiology        $153.07
# 18     2024/12/16     Daniel Jacobson      General        Rs329.3
# 19     2025/05/23        Kayla Savage    Neurology        €135.45
#
#    follow_up_required
# 0                   1
# 1                   Y
# 2                   Y
# 3                  No
# 4                   1
# 5                 Yes
# 6                  No
# 7                  No
# 8                 Yes
# 9                 Yes
# 10                  Y
# 11                Yes
# 12                  N
# 13                  Y
# 14                  N
# 15                  Y
# 16                Yes
# 17                  Y
# 18                  1
# 19                Yes

# %%
#Create a copy of the dataset
clinic_copy = clinic.copy()

# %%
#Dataset information
clinic.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   patient_id          1000 non-null   int64
#  1   patient_name        1000 non-null   str
#  2   age                 1000 non-null   int64
#  3   gender              950 non-null    str
#  4   appointment_date    1000 non-null   str
#  5   booking_date        1000 non-null   str
#  6   doctor              1000 non-null   str
#  7   department          1000 non-null   str
#  8   billing_amount      950 non-null    str
#  9   follow_up_required  1000 non-null   str
# dtypes: int64(2), str(8)
# memory usage: 146.4 KB

# %%
#Check for duplicates
clinic[clinic.duplicated()]
# Out:
# Empty DataFrame
# Columns: [patient_id, patient_name, age, gender, appointment_date, booking_date, doctor, department, billing_amount, follow_up_required]
# Index: []

# %%
#Statistic information of the dataset
clinic.describe(include='all')
# Out:
#          patient_id   patient_name          age gender appointment_date  \
# count   1000.000000           1000  1000.000000    950             1000
# unique          NaN            988          NaN      8              735
# top             NaN  Regina Wilson          NaN      0       2026/02/11
# freq            NaN              2          NaN    129                4
# mean    1050.521000            NaN    53.750000    NaN              NaN
# std       28.888581            NaN    21.137604    NaN              NaN
# min     1000.000000            NaN    18.000000    NaN              NaN
# 25%     1025.000000            NaN    34.000000    NaN              NaN
# 50%     1051.000000            NaN    55.000000    NaN              NaN
# 75%     1075.000000            NaN    71.000000    NaN              NaN
# max     1100.000000            NaN    90.000000    NaN              NaN
#
#          booking_date          doctor department billing_amount  \
# count            1000            1000       1000            950
# unique            822             990          4            949
# top     August 05, 24  Jennifer Adams  Neurology        €243.78
# freq                3               2        273              2
# mean              NaN             NaN        NaN            NaN
# std               NaN             NaN        NaN            NaN
# min               NaN             NaN        NaN            NaN
# 25%               NaN             NaN        NaN            NaN
# 50%               NaN             NaN        NaN            NaN
# 75%               NaN             NaN        NaN            NaN
# max               NaN             NaN        NaN            NaN
#
#        follow_up_required
# count                1000
# unique                  6
# top                     0
# freq                  185
# mean                  NaN
# std                   NaN
# min                   NaN
# 25%                   NaN
# 50%                   NaN
# 75%                   NaN
# max                   NaN

# %%
#Check corresponding missing rows of a column
clinic[clinic["gender"].isna()]
# Out:
#      patient_id       patient_name  age gender  appointment_date  \
# 4          1092     Benjamin Brown   45    NaN        2026/03/07
# 36         1003      Katelyn Smith   19    NaN    October 16, 25
# 43         1063     Edward Sanders   29    NaN        2025/09/16
# 64         1077     Jennifer Stark   34    NaN        06/29/2025
# 70         1095      Jessica Heath   86    NaN        2025/06/25
# 84         1093        Craig Nixon   55    NaN        2025/10/12
# 91         1040      Chelsea Burns   62    NaN   December 29, 25
# 102        1088         Sarah Hahn   60    NaN       19-Mar-2026
# 108        1018      Monica Horton   53    NaN       11-Oct-2025
# 125        1053       John Johnson   81    NaN       23-Apr-2025
# 164        1082        Gary Walker   87    NaN      March 26, 25
# 173        1084        Troy Taylor   52    NaN   December 28, 25
# 208        1048        Walter Webb   33    NaN        2025/09/26
# 222        1060   Stephanie Bryant   32    NaN        2026/01/02
# 244        1015      Stephen Hicks   88    NaN        10/19/2025
# 248        1093    Whitney Bradley   31    NaN       27-May-2025
clinic[clinic.isnull().any(axis=1)]
# Out:
#      patient_id        patient_name  age gender  appointment_date  \
# 4          1092      Benjamin Brown   45    NaN        2026/03/07
# 5          1057           Joe Sharp   78      1  September 26, 25
# 33         1041         Nicole Shaw   20   male        05/07/2025
# 36         1003       Katelyn Smith   19    NaN    October 16, 25
# 43         1063      Edward Sanders   29    NaN        2025/09/16
# ..          ...                 ...  ...    ...               ...
# 933        1034      Amanda Douglas   90      1        03/07/2026
# 937        1048        Ashley Black   84      F        05/29/2025
# 938        1068         Wendy Parks   40   male        2026/02/14
# 956        1016  Jocelyn Strickland   22      M       30-Apr-2025
# 984        1081     Courtney Wright   43    NaN       26-Jul-2025
#
#      booking_date            doctor   department billing_amount  \
# 4      08/17/2024  Andrea Hernandez      General         $84.44
# 5      08/31/2025   Kimberly Fields      General            NaN
# 33     01/19/2025  Mr. Brian Morton    Neurology            NaN
# 36     09/21/2025      Robert Henry    Neurology        $481.44
# 43   April 29, 25     Steven Bailey  Orthopedics       Rs479.77
# ..            ...               ...          ...            ...
# 933    2024/06/25  Gregory Gonzalez      General            NaN
# 937   29-Jan-2025     Dennis Murphy    Neurology            NaN
# 938   09-Sep-2025  Melissa Williams    Neurology            NaN
# 956   July 10, 24      Vincent Kemp   Cardiology            NaN
# 984    May 24, 24     Daniel Morris  Orthopedics       Rs362.65
#
#     follow_up_required
# 4                    1
# 5                  Yes
# 33                   Y
# 36                   0
# 43                   0
# ..                 ...
# 933                  0
# 937                  N
# 938                  1
# 956                  N
# 984                  1
#
# [98 rows x 10 columns]

# %%
#Remove the missing rows from the dataset
clinic.dropna(inplace=True)

# %%
#Cross-checking the dataset information for verification
clinic.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 902 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   patient_id          902 non-null    int64
#  1   patient_name        902 non-null    str
#  2   age                 902 non-null    int64
#  3   gender              902 non-null    str
#  4   appointment_date    902 non-null    str
#  5   booking_date        902 non-null    str
#  6   doctor              902 non-null    str
#  7   department          902 non-null    str
#  8   billing_amount      902 non-null    str
#  9   follow_up_required  902 non-null    str
# dtypes: int64(2), str(8)
# memory usage: 140.1 KB

# %%
#Rename the follow_up_required column
clinic = clinic.rename(columns= {"follow_up_required":"follow_up"})

# %%
#Capitalize the column heads
clinic.columns = clinic.columns.str.replace("_"," ").str.title()

# %%
#Better view of values under gender column
clinic["Gender"].unique()
# Out:
# <ArrowStringArray>
# ['female', 'F', 'M', 'Female', 'male', '1', 'Male', '0']
# Length: 8, dtype: str

# %%
#Changing the gender values to male or female
clinic["Gender"] = clinic["Gender"].replace(["F","Female","0"],"female").replace(["M","Male","1"],"male")

# %%
#Better view of values under follow up column
clinic["Follow Up"].unique()
# Out:
# <ArrowStringArray>
# ['1', 'Y', 'No', 'Yes', 'N', '0']
# Length: 6, dtype: str

# %%
#View of the dataset to determine which class 0/1 belongs
clinic.sample(20) #Done 3x
# Out:
#      Patient Id          Patient Name  Age  Gender  Appointment Date  \
# 141        1093          Alexander Le   77  female    January 20, 26
# 806        1047             Amy Baird   51    male       01-Nov-2025
# 848        1026            Kim Morris   56  female   December 20, 25
# 875        1054        Lori Henderson   50  female        2025/06/05
# 16         1027           Kelly Olsen   72    male     August 27, 25
# 148        1011        Nathaniel Wood   66    male       29-Apr-2025
# 287        1003        Stephen Butler   81  female        May 22, 25
# 579        1001       Jacqueline West   70    male        01/19/2026
# 110        1013     Dr. Peggy Mendoza   60  female       12-Apr-2025
# 377        1016        Kara Schneider   81  female       21-Jul-2025
# 35         1051          Leslie Silva   26    male        2025/06/07
# 972        1082      Joseph Rodriguez   69  female        2025/05/25
# 966        1069          Monica Jones   18    male        2025/10/17
# 971        1042           Dawn Bryant   48  female       14-Jun-2025
# 596        1031         John Gonzalez   44    male    January 19, 26
# 741        1000         Angela Rogers   18    male        08/14/2025
# 894        1096  Patricia Johnson DDS   70    male       June 12, 25
# 753        1004        Darin Caldwell   54    male  September 03, 25
# 333        1015          Nicole Evans   86  female        2025/08/13
# 376        1024        Natalie Miller   55  female       12-Oct-2025
#
#        Booking Date              Doctor   Department Billing Amount Follow Up
# 141      04/04/2024      Cynthia Booker    Neurology        £252.22         1
# 806      09/28/2025         Diana Jones    Neurology        £262.16         1
# 848     24-Jun-2025      Michael Morris      General        $197.66         N
# 875     19-Dec-2024       Terri Stewart      General       Rs496.31        No
# 16      13-Feb-2025  Christopher Bryant   Cardiology        £252.38       Yes
# 148     07-Apr-2025           Alec Hill      General       Rs413.21         1
# 287      2024/04/15    Shannon Martinez    Neurology        £209.67         Y
# 579      2025/01/17       Steven Walker      General        £148.74         Y
# 110      01/23/2025      Ashley Flowers    Neurology         €96.94       Yes
# 377      2024/07/08          Ivan Russo      General        £456.26         1
# 35      09-Dec-2024       Thomas Brandt  Orthopedics        $340.25       Yes
# 972      06/15/2024      Douglas Foster   Cardiology         €94.37         1
# 966     07-May-2024       Cheryl Bailey   Cardiology       Rs363.94        No
# 971      03/21/2025      Charles Nguyen   Cardiology       Rs164.15         Y
# 596     June 14, 24      Richard Medina  Orthopedics        €284.66         N
# 741     10-Apr-2025     Dr. Brian Smith  Orthopedics       Rs362.08         0
# 894      2024/11/27            Ana Hunt    Neurology        £144.89       Yes
# 753     20-Feb-2025    Danielle Pacheco   Cardiology        €185.15        No
# 333      2024/09/21       Ashley Cuevas   Cardiology       Rs459.41         Y
# 376  October 28, 24       Derrick Glass      General         €56.37         Y

# %%
#Change follow_up column values to yes or no
clinic["Follow Up"] = clinic["Follow Up"].replace(["1","Y","Yes"],"yes").replace(["0","N","No"],"no")

# %%
#Convert the booking and appointment date to datetime data type
clinic["Appointment Date"] = pd.to_datetime(clinic["Appointment Date"], format="mixed")
clinic["Booking Date"] = pd.to_datetime(clinic["Booking Date"], format="mixed")

# %%
#Create a new column for the billing amount that has only the euros as currency.
